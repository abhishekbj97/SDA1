# %%
# Importing
import sklearn
import pandas as pd

# Load the dataset
bos_hou = load_boston()

# Create the dataframe
column_name = bos_hou.feature_names
df_boston = pd.DataFrame(bos_hou.data)
df_boston.columns = column_name
df_boston.head()

''' Detection '''
# IQR
Q1 = np.percentile(df_boston['DIS'], 25,
				interpolation = 'midpoint')

Q3 = np.percentile(df_boston['DIS'], 75,
				interpolation = 'midpoint')
IQR = Q3 - Q1

print("Old Shape: ", df_boston.shape)

# Upper bound
upper=Q3+1.5*IQR
upper_array=np.array(df_boston[‘DIS’]>=upper)
# Lower bound
lower=Q1-1.5*IQR
lower_array=np.array(df_boston[‘DIS’]<=lower)
# Removing the outliers
df_boston.drop(upper_array[0],inplace=True)
df_boston.drop(lower_array[0],inplace=True)

print("New Shape: ", df_boston.shape)

# %%
# Importing
import sklearn
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv('global_emissions.csv')
dataframe
# Out:
#       Year Country.Name Country.Code   Country.GDP  Country.Population  \
# 0     1992  Afghanistan          AFG  1.267754e+10            14485543
# 1     1993  Afghanistan          AFG  9.834581e+09            15816601
# 2     1994  Afghanistan          AFG  7.919857e+09            17075728
# 3     1995  Afghanistan          AFG  1.230753e+10            18110662
# 4     1996  Afghanistan          AFG  1.207013e+10            18853444
# ...    ...          ...          ...           ...                 ...
# 2479  2014      Vietnam          VNM  5.098024e+11            91713848
# 2480  2015      Vietnam          VNM  5.439311e+11            92677080
# 2481  2016      Vietnam          VNM  5.776835e+11            93640440
# 2482  2017      Vietnam          VNM  6.177747e+11            94600640
# 2483  2018      Vietnam          VNM  6.614884e+11            95545960
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(np.log(dataframe["Emissions.Production.CH4"]))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fed58fe0af0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fed58ff10d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fed58fe0820>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fed58ff1670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fed58ff1940>],
#  'means': []}

# %%
plt.boxplot(np.log(dataframe["Emissions.Production.N2O"]))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fed3846db20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fed3847d100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fed3846d850>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fed3847d6a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fed3847d970>],
#  'means': []}

# %%
''' Detection '''
# IQR
Q1 = np.percentile(dataframe['Emissions.Production.CH4'], 25, interpolation = 'midpoint')
Q1
# Out:
# 7.46

# %%
Q3 = np.percentile(dataframe['Emissions.Production.CH4'], 75, interpolation = 'midpoint')
Q3
# Out:
# 66.035

# %%
IQR = Q3 - Q1
IQR
# Out:
# 58.574999999999996

# %%
print("Old Shape: ", dataframe.shape)
# Out:
# Old Shape:  (2484, 20)

# %%
# Upper bound
upper=Q3+1.5*IQR
upper_array=np.array(dataframe['Emissions.Production.CH4']>=upper)

# %%
upper_array.sum()
# Out:
# 207

# %%
# Lower bound
lower=Q1-1.5*IQR
lower_array=np.array(dataframe['Emissions.Production.CH4']<=lower)

# %%
lower_array.sum()
# Out:
# 0

# %%
# Removing the outliers
dataframe.drop(upper_array[0],inplace=True)
dataframe.drop(lower_array[0],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/8v/x5wpqfrj75z_n1t_mwpy_8vm0000gn/T/ipykernel_27250/555832501.py in <module>
#       1 # Removing the outliers
# ----> 2 dataframe.drop(upper_array[0],inplace=True)
#       3 dataframe.drop(lower_array[0],inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
# Removing the outliers
dataframe.drop(upper_array[0],inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/8v/x5wpqfrj75z_n1t_mwpy_8vm0000gn/T/ipykernel_27250/3709088197.py in <module>
#       1 # Removing the outliers
# ----> 2 dataframe.drop(upper_array[0],inplace=True,axis=1)
#       3
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
print("New Shape: ", dataframe.shape)
# Out:
# New Shape:  (2484, 20)

# %% [markdown]
# # Boston USA  prac

# %%
# Importing
import sklearn
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
bos_hou = load_boston()

# Create the dataframe
column_name = bos_hou.feature_names
df_boston = pd.DataFrame(bos_hou.data)
df_boston.columns = column_name
df_boston.head()
# Out:
# /Users/abhishekbarandoorujanavejirao/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
# ...

# %%
# Box Plot
import seaborn as sns
sns.boxplot(df_boston['DIS'])
# Out:
# /Users/abhishekbarandoorujanavejirao/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DIS'>

# %%
# Position of the Outlier
import numpy as np
print(np.where(df_boston['DIS']>10))
# Out:
# (array([351, 352, 353, 354, 355]),)

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df_boston['INDUS'], df_boston['TAX'])

# x-axis label
ax.set_xlabel('(Proportion non-retail business acres)/(town)')

# y-axis label
ax.set_ylabel('(Full-value property-tax rate)/( $10,000)')
plt.show()

# %%
# Position of the Outlier
print(np.where((df_boston['INDUS']>20) & (df_boston['TAX']>600)))
# Out:
# (array([488, 489, 490, 491, 492]),)

# %%
# Z score
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(df_boston['DIS']))
print(z)
# Out:
# 0      0.140214
# 1      0.557160
# 2      0.557160
# 3      1.077737
# 4      1.077737
#          ...
# 501    0.625796
# 502    0.716639
# 503    0.773684
# 504    0.668437
# 505    0.613246
# Name: DIS, Length: 506, dtype: float64

# %%
threshold = 3

# Position of the outlier
print(np.where(z > 3))
# Out:
# (array([351, 352, 353, 354, 355]),)

# %%
# IQR
Q1 = np.percentile(df_boston['DIS'], 25,
				interpolation = 'midpoint')

Q3 = np.percentile(df_boston['DIS'], 75,
				interpolation = 'midpoint')
IQR = Q3 - Q1

# %%
IQR
# Out:
# 3.0646000000000004

# %%
# Above Upper bound
upper=Q3+1.5*IQR
upper_array=np.array(df_boston['DIS']>=upper)
print('Upper Bound:',upper)
print(upper_array)

#Below Lower bound
lower=Q1-1.5*IQR
lower_array=np.array(df_boston['DIS']<=lower)
print('Lower Bound:',lower)
print(lower_array)
# Out:
# Upper Bound: 9.76185
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
# ...

# %%
print('Upper Bound:',upper)
print('Lower Bound:',lower)
# Out:
# Upper Bound: 9.76185
# Lower Bound: -2.496550000000001

# %%
df_boston.drop(upper_array[0],inplace=True)
df_boston.drop(lower_array[0],inplace=True)
 
print("New Shape: ", df_boston.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/8v/x5wpqfrj75z_n1t_mwpy_8vm0000gn/T/ipykernel_27250/337993847.py in <module>
# ----> 1 df_boston.drop(upper_array[0],inplace=True)
#       2 df_boston.drop(lower_array[0],inplace=True)
#       3
#       4 print("New Shape: ", df_boston.shape)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
# ...

# %% [markdown]
# # new way

# %%
dataframe
# Out:
#       Year Country.Name Country.Code   Country.GDP  Country.Population  \
# 0     1992  Afghanistan          AFG  1.267754e+10            14485543
# 1     1993  Afghanistan          AFG  9.834581e+09            15816601
# 2     1994  Afghanistan          AFG  7.919857e+09            17075728
# 3     1995  Afghanistan          AFG  1.230753e+10            18110662
# 4     1996  Afghanistan          AFG  1.207013e+10            18853444
# ...    ...          ...          ...           ...                 ...
# 2479  2014      Vietnam          VNM  5.098024e+11            91713848
# 2480  2015      Vietnam          VNM  5.439311e+11            92677080
# 2481  2016      Vietnam          VNM  5.776835e+11            93640440
# 2482  2017      Vietnam          VNM  6.177747e+11            94600640
# 2483  2018      Vietnam          VNM  6.614884e+11            95545960
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
dataframe_drop_new = dataframe.drop(['Country.Name','Country.Code'],axis=1)
dataframe_drop_new
# Out:
#       Year   Country.GDP  Country.Population  Emissions.Production.CH4  \
# 0     1992  1.267754e+10            14485543                      7.13
# 1     1993  9.834581e+09            15816601                      7.21
# 2     1994  7.919857e+09            17075728                      7.47
# 3     1995  1.230753e+10            18110662                      7.83
# 4     1996  1.207013e+10            18853444                      8.67
# ...    ...           ...                 ...                       ...
# 2479  2014  5.098024e+11            91713848                     84.93
# 2480  2015  5.439311e+11            92677080                     83.85
# 2481  2016  5.776835e+11            93640440                     81.85
# 2482  2017  6.177747e+11            94600640                     81.28
# 2483  2018  6.614884e+11            95545960                     81.42
#
#       Emissions.Production.N2O  Emissions.Production.CO2.Cement  \
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dataframe_drop_new)
z_scores
# Out:
#           Year  Country.GDP  Country.Population  Emissions.Production.CH4  \
# 0    -1.669046    -0.392303           -0.262534                 -0.430149
# 1    -1.540658    -0.393736           -0.255278                 -0.429617
# 2    -1.412270    -0.394702           -0.248414                 -0.427889
# 3    -1.283881    -0.392490           -0.242772                 -0.425496
# 4    -1.155493    -0.392610           -0.238723                 -0.419911
# ...        ...          ...                 ...                       ...
# 2479  1.155493    -0.141724            0.158466                  0.087058
# 2480  1.283881    -0.124521            0.163717                  0.079878
# 2481  1.412270    -0.107508            0.168969                  0.066582
# 2482  1.540658    -0.087299            0.174203                  0.062793
# 2483  1.669046    -0.065265            0.179356                  0.063724
#
#       Emissions.Production.N2O  Emissions.Production.CO2.Cement  \
# ...

# %%
print(z_scores)
# Out:
#           Year  Country.GDP  Country.Population  Emissions.Production.CH4  \
# 0    -1.669046    -0.392303           -0.262534                 -0.430149
# 1    -1.540658    -0.393736           -0.255278                 -0.429617
# 2    -1.412270    -0.394702           -0.248414                 -0.427889
# 3    -1.283881    -0.392490           -0.242772                 -0.425496
# 4    -1.155493    -0.392610           -0.238723                 -0.419911
# ...        ...          ...                 ...                       ...
# 2479  1.155493    -0.141724            0.158466                  0.087058
# 2480  1.283881    -0.124521            0.163717                  0.079878
# 2481  1.412270    -0.107508            0.168969                  0.066582
# 2482  1.540658    -0.087299            0.174203                  0.062793
# 2483  1.669046    -0.065265            0.179356                  0.063724
#
#       Emissions.Production.N2O  Emissions.Production.CO2.Cement  \
# ...

# %%
abs_z_scores = np.abs(z_scores)
print(abs_z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
new_df = dataframe_drop_new[filtered_entries]

print(new_df)
# Out:
#           Year  Country.GDP  Country.Population  Emissions.Production.CH4  \
# 0     1.669046     0.392303            0.262534                  0.430149
# 1     1.540658     0.393736            0.255278                  0.429617
# 2     1.412270     0.394702            0.248414                  0.427889
# 3     1.283881     0.392490            0.242772                  0.425496
# 4     1.155493     0.392610            0.238723                  0.419911
# ...        ...          ...                 ...                       ...
# 2479  1.155493     0.141724            0.158466                  0.087058
# 2480  1.283881     0.124521            0.163717                  0.079878
# 2481  1.412270     0.107508            0.168969                  0.066582
# 2482  1.540658     0.087299            0.174203                  0.062793
# 2483  1.669046     0.065265            0.179356                  0.063724
#
#       Emissions.Production.N2O  Emissions.Production.CO2.Cement  \
# ...

# %%
print(abs_z_scores)
# Out:
#           Year  Country.GDP  Country.Population  Emissions.Production.CH4  \
# 0     1.669046     0.392303            0.262534                  0.430149
# 1     1.540658     0.393736            0.255278                  0.429617
# 2     1.412270     0.394702            0.248414                  0.427889
# 3     1.283881     0.392490            0.242772                  0.425496
# 4     1.155493     0.392610            0.238723                  0.419911
# ...        ...          ...                 ...                       ...
# 2479  1.155493     0.141724            0.158466                  0.087058
# 2480  1.283881     0.124521            0.163717                  0.079878
# 2481  1.412270     0.107508            0.168969                  0.066582
# 2482  1.540658     0.087299            0.174203                  0.062793
# 2483  1.669046     0.065265            0.179356                  0.063724
#
#       Emissions.Production.N2O  Emissions.Production.CO2.Cement  \
# ...

# %%
new_df.head()
# Out:
#    Year   Country.GDP  Country.Population  Emissions.Production.CH4  \
# 0  1992  1.267754e+10            14485543                      7.13
# 1  1993  9.834581e+09            15816601                      7.21
# 2  1994  7.919857e+09            17075728                      7.47
# 3  1995  1.230753e+10            18110662                      7.83
# 4  1996  1.207013e+10            18853444                      8.67
#
#    Emissions.Production.N2O  Emissions.Production.CO2.Cement  \
# 0                      2.89                            0.046
# 1                      2.93                            0.047
# 2                      2.76                            0.047
# 3                      2.88                            0.047
# 4                      3.12                            0.047
#
#    Emissions.Production.CO2.Coal  Emissions.Production.CO2.Gas  \
# 0                          0.022                         0.363
# ...

# %%
new_df.shape
# Out:
# (2333, 18)

# %%
import seaborn as sns
sns.boxplot(new_df['Emissions.Production.CH4'])
# Out:
# /Users/abhishekbarandoorujanavejirao/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Emissions.Production.CH4'>

# %%
new_df
# Out:
#       Year   Country.GDP  Country.Population  Emissions.Production.CH4  \
# 0     1992  1.267754e+10            14485543                      7.13
# 1     1993  9.834581e+09            15816601                      7.21
# 2     1994  7.919857e+09            17075728                      7.47
# 3     1995  1.230753e+10            18110662                      7.83
# 4     1996  1.207013e+10            18853444                      8.67
# ...    ...           ...                 ...                       ...
# 2479  2014  5.098024e+11            91713848                     84.93
# 2480  2015  5.439311e+11            92677080                     83.85
# 2481  2016  5.776835e+11            93640440                     81.85
# 2482  2017  6.177747e+11            94600640                     81.28
# 2483  2018  6.614884e+11            95545960                     81.42
#
#       Emissions.Production.N2O  Emissions.Production.CO2.Cement  \
# ...

# %%
# Importing
import sklearn
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np

# Load the dataset
bos_hou = load_boston()

# Create the dataframe
column_name = bos_hou.feature_names
df_boston = pd.DataFrame(bos_hou.data)
df_boston.columns = column_name
df_boston.head()

''' Detection '''
# IQR
Q1 = np.percentile(df_boston['DIS'], 25,
				interpolation = 'midpoint')

Q3 = np.percentile(df_boston['DIS'], 75,
				interpolation = 'midpoint')
IQR = Q3 - Q1

print("Old Shape: ", df_boston.shape)

# Upper bound
upper=Q3+1.5*IQR
upper_array=np.array(df_boston['DIS']>=upper)
# Lower bound
lower=Q1-1.5*IQR
lower_array=np.array(df_boston['DIS']<=lower)
# Removing the outliers
df_boston.drop(upper_array[0],inplace=True)
df_boston.drop(lower_array[0],inplace=True)

print("New Shape: ", df_boston.shape)
# Out:
# Old Shape:  (506, 13)
# /Users/abhishekbarandoorujanavejirao/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
# ...

# %%
#new

# %%
boston = load_boston()
x = boston.data
y = boston.target
columns = boston.feature_names#create the dataframe
boston_df = pd.DataFrame(boston.data)
boston_df.columns = columns
boston_df.head()
# Out:
# /Users/abhishekbarandoorujanavejirao/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
# ...

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(boston_df))
print(z)
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0    0.419782  0.284830  1.287909  0.272599  0.144217  0.413672  0.120013
# 1    0.417339  0.487722  0.593381  0.272599  0.740262  0.194274  0.367166
# 2    0.417342  0.487722  0.593381  0.272599  0.740262  1.282714  0.265812
# 3    0.416750  0.487722  1.306878  0.272599  0.835284  1.016303  0.809889
# 4    0.412482  0.487722  1.306878  0.272599  0.835284  1.228577  0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.413229  0.487722  0.115738  0.272599  0.158124  0.439316  0.018673
# 502  0.415249  0.487722  0.115738  0.272599  0.158124  0.234548  0.288933
# 503  0.413447  0.487722  0.115738  0.272599  0.158124  0.984960  0.797449
# 504  0.407764  0.487722  0.115738  0.272599  0.158124  0.725672  0.736996
# 505  0.415000  0.487722  0.115738  0.272599  0.158124  0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#        200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#        220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#        277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#        357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#        380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#        416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#        437, 438, 445, 450, 454, 455, 456, 457, 466]), array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#         5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#         3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#         0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
# ...

# %%
z = np.abs(stats.zscore(boston_df['DIS']))

# %%
z
# Out:
# 0      0.140214
# 1      0.557160
# 2      0.557160
# 3      1.077737
# 4      1.077737
#          ...
# 501    0.625796
# 502    0.716639
# 503    0.773684
# 504    0.668437
# 505    0.613246
# Name: DIS, Length: 506, dtype: float64

# %%
# Position of the outlier
print(np.where(z > 3))
# Out:
# (array([351, 352, 353, 354, 355]),)

# %%
Q1 = boston_df.quantile(0.25)
Q3 = boston_df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# CRIM         3.595038
# ZN          12.500000
# INDUS       12.910000
# CHAS         0.000000
# NOX          0.175000
# RM           0.738000
# AGE         49.050000
# DIS          3.088250
# RAD         20.000000
# TAX        387.000000
# PTRATIO      2.800000
# B           20.847500
# LSTAT       10.005000
# dtype: float64

# %%
print("Old data set shape with Outliers ",boston_df.shape)
boston_df_out = boston_df[~((boston_df < (Q1 - 1.5 * IQR)) |(boston_df > (Q3 + 1.5 * IQR))).any(axis=1)]
print("New data set shape without Outliers ",boston_df_out.shape)
# Out:
# Old data set shape with Outliers  (506, 13)
# New data set shape without Outliers  (274, 13)

# %%
boston_df_out
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
def remove_outlier_Hampel(df):
    med=df.median()
    List=abs(df-med)
    cond=List.median()*4.5
    good_list=List[~(List>cond)]
    return good_list

# %%
print("size of the CRIM column before outlier removal is",boston_df['DIS'].shape[0])
df_outlier_removed=remove_outlier_Hampel(boston_df['DIS'])
print("size of the CRIM column after outlier removal is",df_outlier_removed.shape[0])
plt.subplot(1,2,1)
sns.boxplot(data=boston_df['DIS'])
plt.xticks(rotation=90)
plt.ylabel('Price ($)')
# Finding the index's of outlier items 
ind_diff=boston_df.index.difference(df_outlier_removed.index)
# dropping all rows from the data frame which having outliers
for i in range(0, len(ind_diff),1):
    boston_df.drop([ind_diff[i]],inplace=True)
plt.subplot(1,2,2)
sns.boxplot(data=boston_df['DIS'])
plt.xticks(rotation=90)
# Out:
# size of the CRIM column before outlier removal is 506
# size of the CRIM column after outlier removal is 496
# (array([0]), [Text(0, 0, '0')])

# %%
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...
