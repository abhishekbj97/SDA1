# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
import pandas as pd

# import matplotlib
# matplotlib.use('GTK3Agg')


# Load CSV and columns
df = pd.read_csv("global_emissions.csv")

# %%
df
# Out:
#       Year Country.Name Country.Code   Country.GDP  Country.Population  \
# 0     1992  Afghanistan          AFG  1.267754e+10            14485543
# 1     1993  Afghanistan          AFG  9.834581e+09            15816601
# 2     1994  Afghanistan          AFG  7.919857e+09            17075728
# 3     1995  Afghanistan          AFG  1.230753e+10            18110662
# 4     1996  Afghanistan          AFG  1.207013e+10            18853444
# ...    ...          ...          ...           ...                 ...
# 2479  2014      Vietnam          VNM  5.098024e+11            91713848
# 2480  2015      Vietnam          VNM  5.439311e+11            92677080
# 2481  2016      Vietnam          VNM  5.776835e+11            93640440
# 2482  2017      Vietnam          VNM  6.177747e+11            94600640
# 2483  2018      Vietnam          VNM  6.614884e+11            95545960
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
Y = df['Year']
X = df['Emissions.Production.CH4']

X=X.values.reshape(len(X),1)
Y=Y.values.reshape(len(Y),1)

# Split the data into training/testing sets
X_train = X[:-1242]
X_test = X[-1242:]

# Split the targets into training/testing sets
Y_train = Y[:-1242]
Y_test = Y[-1242:]

# Plot outputs
plt.scatter(X_test, Y_test,  color='black')
plt.title('Test Data')
plt.xlabel('Emission')
plt.ylabel('Year')
plt.xticks(())
plt.yticks(())

plt.show()

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, Y_train)

# Plot outputs
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3)

# %%
print( str(round(regr.predict(5000))) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/8v/x5wpqfrj75z_n1t_mwpy_8vm0000gn/T/ipykernel_16393/3778812878.py in <module>
# ----> 1 print( str(round(regr.predict(5000))) )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     343         check_is_fitted(self)
#     344
# --> 345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     347
#
# ...

# %%
df.loc[df['Year'] == 1992]
# Out:
#       Year   Country.Name Country.Code   Country.GDP  Country.Population  \
# 0     1992    Afghanistan          AFG  1.267754e+10            14485543
# 27    1992        Albania          ALB  8.745681e+09             3245887
# 54    1992        Algeria          DZA  1.279827e+11            27028330
# 81    1992         Angola          AGO  1.236343e+10            12657361
# 108   1992      Argentina          ARG  4.166798e+11            33529320
# ...    ...            ...          ...           ...                 ...
# 2349  1992  United States          USA  9.572148e+12           256990608
# 2376  1992        Uruguay          URY  3.559816e+10             3154459
# 2403  1992     Uzbekistan          UZB  1.195108e+11            21375114
# 2430  1992      Venezuela          VEN  3.010702e+11            20557694
# 2457  1992        Vietnam          VNM  1.254965e+11            70883488
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
name = df['Country.Name']
# price = df['Emissions.Production.CH4'].head(12)
price = df['Emissions.Production.CH4']
# Figure Size
fig = plt.figure(figsize =(12, 4))

# Horizontal Bar Plot
plt.bar(name[0:], price[0:])
plt.xticks(rotation = 90)
# Show Plot
plt.show()

# %%
name = df['Country.Name']
# price = df['Emissions.Production.CH4'].head(12)
price = df['Emissions.Production.CH4']
# Figure Size
fig = plt.figure(figsize =(12, 10))

# Horizontal Bar Plot
#plt.bar(name[0:], price[0:])
plt.bar(price[0:], name[0:])
# Show Plot
plt.show()

# %%
# name = df['Country.Name'].head(12)
# price = df['Emissions.Production.CH4'].head(12)
Country = df['Country.Name'].head(20)
Emissions = df['Emissions.Production.CH4'].head(20)

# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(Country, Emissions)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
		linestyle ='-.', linewidth = 0.5,
		alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
	plt.text(i.get_width()+0.2, i.get_y()+0.5,
			str(round((i.get_width()), 2)),
			fontsize = 10, fontweight ='bold',
			color ='grey')

# Add Plot Title
ax.set_title('Sports car and their price in crore',
			loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
		color ='grey', ha ='right', va ='bottom',
		alpha = 0.7)

# Show Plot
plt.show()
# Out:
# /var/folders/8v/x5wpqfrj75z_n1t_mwpy_8vm0000gn/T/ipykernel_16393/3906648882.py:25: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b = True, color ='grey',

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Read CSV into pandas
data = pd.read_csv(r"global_emissions.csv")
data.head()
df = pd.DataFrame(data)

# name = df['Country.Name'].head(12)
# price = df['Emissions.Production.CH4'].head(12)
Country = df['Country.Name']
Emissions = df['Emissions.Production.CH4']

# Figure Size
fig, ax = plt.subplots(figsize =(30, 30))

# Horizontal Bar Plot
ax.barh(Country, Emissions)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
		linestyle ='-.', linewidth = 0.5,
		alpha = 0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
	plt.text(i.get_width()+0.2, i.get_y()+0.5,
			str(round((i.get_width()), 2)),
			fontsize = 10, fontweight ='bold',
			color ='grey')

# Add Plot Title
ax.set_title('Sports car and their price in crore',
			loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
		color ='grey', ha ='right', va ='bottom',
		alpha = 0.7)

# Show Plot
plt.show()
# Out:
# /var/folders/8v/x5wpqfrj75z_n1t_mwpy_8vm0000gn/T/ipykernel_16393/3099232988.py:33: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b = True, color ='grey',

# %%
df.loc[df['Year'] == 1993]
# Out:
#       Year   Country.Name Country.Code   Country.GDP  Country.Population  \
# 1     1993    Afghanistan          AFG  9.834581e+09            15816601
# 28    1993        Albania          ALB  9.636359e+09             3195196
# 55    1993        Algeria          DZA  1.302758e+11            27635518
# 82    1993         Angola          AGO  9.985482e+09            13075044
# 109   1993      Argentina          ARG  4.447802e+11            33970100
# ...    ...            ...          ...           ...                 ...
# 2350  1993  United States          USA  9.834941e+12           259532128
# 2377  1993        Uruguay          URY  3.647110e+10             3177734
# 2404  1993     Uzbekistan          UZB  1.149181e+11            21861974
# 2431  1993      Venezuela          VEN  3.032957e+11            21016900
# 2458  1993        Vietnam          VNM  1.351247e+11            72300304
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
df.loc[df['Year'] == 1994]
# Out:
#       Year   Country.Name Country.Code   Country.GDP  Country.Population  \
# 2     1994    Afghanistan          AFG  7.919857e+09            17075728
# 29    1994        Albania          ALB  1.059613e+10             3146518
# 56    1994        Algeria          DZA  1.342799e+11            28213778
# 83    1994         Angola          AGO  1.076081e+10            13503753
# 110   1994      Argentina          ARG  4.729267e+11            34402668
# ...    ...            ...          ...           ...                 ...
# 2351  1994  United States          USA  1.023202e+13           262241216
# 2378  1994        Uruguay          URY  3.903633e+10             3201149
# 2405  1994     Uzbekistan          UZB  1.072421e+11            22336202
# 2432  1994      Venezuela          VEN  2.977813e+11            21474552
# 2459  1994        Vietnam          VNM  1.465041e+11            73651216
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
df_1995 = df.loc[df['Year'] == 1995]

# %%
df_1995
# Out:
#       Year   Country.Name Country.Code   Country.GDP  Country.Population  \
# 3     1995    Afghanistan          AFG  1.230753e+10            18110662
# 30    1995        Albania          ALB  1.160073e+10             3112923
# 57    1995        Algeria          DZA  1.450547e+11            28757788
# 84    1995         Angola          AGO  1.314374e+10            13945205
# 111   1995      Argentina          ARG  4.616010e+11            34828168
# ...    ...            ...          ...           ...                 ...
# 2352  1995  United States          USA  1.051026e+13           265163744
# 2379  1995        Uruguay          URY  3.839953e+10             3224275
# 2406  1995     Uzbekistan          UZB  1.046157e+11            22791034
# 2433  1995      Venezuela          VEN  3.107391e+11            21931088
# 2460  1995        Vietnam          VNM  1.599502e+11            74910464
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
plt.bar(x ='Country.Population', y= 'Emissions.Production.CH4', color='black', height=0.5)
plt.title('Test Data')
plt.xlabel('Emission')
plt.ylabel('Year')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Read CSV into pandas
data = pd.read_csv(r"global_emissions.csv")
data.head()
df = pd.DataFrame(data)

# %%
df
# Out:
#       Year Country.Name Country.Code   Country.GDP  Country.Population  \
# 0     1992  Afghanistan          AFG  1.267754e+10            14485543
# 1     1993  Afghanistan          AFG  9.834581e+09            15816601
# 2     1994  Afghanistan          AFG  7.919857e+09            17075728
# 3     1995  Afghanistan          AFG  1.230753e+10            18110662
# 4     1996  Afghanistan          AFG  1.207013e+10            18853444
# ...    ...          ...          ...           ...                 ...
# 2479  2014      Vietnam          VNM  5.098024e+11            91713848
# 2480  2015      Vietnam          VNM  5.439311e+11            92677080
# 2481  2016      Vietnam          VNM  5.776835e+11            93640440
# 2482  2017      Vietnam          VNM  6.177747e+11            94600640
# 2483  2018      Vietnam          VNM  6.614884e+11            95545960
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
name = df['Country.Name']
# price = df['Emissions.Production.CH4'].head(12)
price = df['Emissions.Production.CH4'].head(2484)
# Figure Size
fig = plt.figure(figsize =(10, 7))

# Horizontal Bar Plot
plt.bar(name[0:10], price[0:10])

# Show Plot
plt.show()
