# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix
from IPython.display import Image
from six import StringIO
from sklearn.tree import export_graphviz
import pydot
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
pip install pydot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_csv('global_emissions.csv')

# %%
data
# Out:
#       Year Country.Name Country.Code   Country.GDP  Country.Population  \
# 0     1992  Afghanistan          AFG  1.267754e+10            14485543
# 1     1993  Afghanistan          AFG  9.834581e+09            15816601
# 2     1994  Afghanistan          AFG  7.919857e+09            17075728
# 3     1995  Afghanistan          AFG  1.230753e+10            18110662
# 4     1996  Afghanistan          AFG  1.207013e+10            18853444
# ...    ...          ...          ...           ...                 ...
# 2479  2014      Vietnam          VNM  5.098024e+11            91713848
# 2480  2015      Vietnam          VNM  5.439311e+11            92677080
# 2481  2016      Vietnam          VNM  5.776835e+11            93640440
# 2482  2017      Vietnam          VNM  6.177747e+11            94600640
# 2483  2018      Vietnam          VNM  6.614884e+11            95545960
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
X = data.drop(['Country.Name','Country.Code'],axis=1)
y = data['Country.Name']

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.30)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtree.predict(X_test)
accuracy = metrics.accuracy_score(y_test,y_pred)
print('Accuracy Score:',accuracy )
# Out:
# Accuracy Score: 0.9718498659517426

# %%
cfMatrix = confusion_matrix(y_test,y_pred)
print(cfMatrix)
# Out:
# [[4 0 0 ... 0 0 0]
#  [0 8 0 ... 0 0 0]
#  [0 0 7 ... 0 0 0]
#  ...
#  [0 0 0 ... 7 0 0]
#  [0 0 0 ... 0 6 0]
#  [0 0 0 ... 0 0 8]]

# %%
cReport = classification_report(y_test,y_pred)
print(cReport)
# Out:
#                         precision    recall  f1-score   support
#
#            Afghanistan       1.00      1.00      1.00         4
#                Albania       1.00      1.00      1.00         8
#                Algeria       1.00      1.00      1.00         7
#                 Angola       1.00      0.88      0.93         8
#              Argentina       1.00      1.00      1.00         8
#                Armenia       1.00      1.00      1.00        11
#              Australia       1.00      1.00      1.00         6
#                Austria       1.00      1.00      1.00         9
#             Azerbaijan       1.00      1.00      1.00         5
#             Bangladesh       1.00      1.00      1.00         8
#                Belarus       1.00      0.83      0.91         6
#                Belgium       1.00      1.00      1.00        10
#                Bolivia       1.00      1.00      1.00         7
# Bosnia and Herzegovina       1.00      0.86      0.92         7
# ...

# %%
conda install python-graphviz
# pip install pydotplus
# Out:
#   File "/var/folders/8v/x5wpqfrj75z_n1t_mwpy_8vm0000gn/T/ipykernel_12228/1560545430.py", line 1
#     conda install python-graphviz
#           ^
# SyntaxError: invalid syntax

# %%
pip install graphviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydotplus
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.7/278.7 kB 2.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24554 sha256=7bba44a6e519e353049a5ba0a9ff096aa5a7e10fcd648d23f40e9c62359cfe8d
#   Stored in directory: /Users/abhishekbarandoorujanavejirao/Library/Caches/pip/wheels/89/e5/de/6966007cf223872eedfbebbe0e074534e72e9128c8fd4b55eb
# Successfully built pydotplus
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data
# Out:
#       Year Country.Name Country.Code   Country.GDP  Country.Population  \
# 0     1992  Afghanistan          AFG  1.267754e+10            14485543
# 1     1993  Afghanistan          AFG  9.834581e+09            15816601
# 2     1994  Afghanistan          AFG  7.919857e+09            17075728
# 3     1995  Afghanistan          AFG  1.230753e+10            18110662
# 4     1996  Afghanistan          AFG  1.207013e+10            18853444
# ...    ...          ...          ...           ...                 ...
# 2479  2014      Vietnam          VNM  5.098024e+11            91713848
# 2480  2015      Vietnam          VNM  5.439311e+11            92677080
# 2481  2016      Vietnam          VNM  5.776835e+11            93640440
# 2482  2017      Vietnam          VNM  6.177747e+11            94600640
# 2483  2018      Vietnam          VNM  6.614884e+11            95545960
#
#       Emissions.Production.CH4  Emissions.Production.N2O  \
# ...

# %%
 
features = list(data.columns[2:])
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data, feature_names=features, filled=True, rounded=True)#feature_names=features
graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph[0].create_png())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pydot.py in create(self, prog, format, encoding)
#    1922         try:
# -> 1923             stdout_data, stderr_data, process = call_graphviz(
#    1924                 program=prog,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     131
# --> 132     process = subprocess.Popen(
#     133         program_with_args,
#
# ~/opt/anaconda3/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
features = list(data.columns[2:])
# dot_data = StringIO()
# export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)
# graph = pydot.graph_from_dot_data(dot_data.getvalue())
# Image(graph[0].create_png())

# %%
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph[0].create_png())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pydot.py in create(self, prog, format, encoding)
#    1922         try:
# -> 1923             stdout_data, stderr_data, process = call_graphviz(
#    1924                 program=prog,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     131
# --> 132     process = subprocess.Popen(
#     133         program_with_args,
#
# ~/opt/anaconda3/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
from graphviz import Digraph
# Create Digraph object
dot = Digraph()

# %%
dot.node('1')
dot.node('2')

# %%
dot.edges(['12'])

# %%
dot
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/graphviz/backend/execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78                 kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79             proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/graphviz/backend/execute.py in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     100
#
# ...

# %%
# !conda install python-graphviz
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/abhishekbarandoorujanavejirao/opt/anaconda3
#
#   added / updated specs:
#     - python-graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.16.0               |       h691a603_2         935 KB
#     expat-2.4.9                |       he9d5cce_0         127 KB
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
# ...

# %% [markdown]
# http://net-informations.com/ds/mla/dtree.htm
